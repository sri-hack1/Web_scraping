# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

headers = {
    "User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/128.0.0.0 Safari/537.36"
           }

# URL
url = "https://www.nobroker.in/property/rent/bangalore/multiple?searchParam=...&radius=2.0&sharedAccomodation=0&city=bangalore&locality=Indiranagar,Jayanagar,Rajajinagar"

# %%
# Getting response
response = requests.get(url, headers = headers)

# Parsing the content
soup = BeautifulSoup(response.text, 'html.parser')

# House_data
house_data = []

# %%
titles = soup.find_all("h2", class_= "flex items-center m-0 heading-6 font-semi-bold")
title = [title.text.strip() for title in titles]

locations = soup.find_all("div", class_ = "mt-0.5p overflow-hidden overflow-ellipsis whitespace-nowrap max-w-70 text-gray-light leading-4 po:mb-0.1p po:max-w-95")
location = [location.text.strip() for location in locations]

emis = soup.find_all("div", class_="flex", id="minimumRent")
emi = [emi.text.strip().replace("â¹", "Rs.") for emi in emis]

areas = soup.find_all("div", class_= "flex", id= "unitCode")
area = [area.text.strip() for area in areas]

prices = soup.find_all("div", class_="font-semi-bold heading-6", id= "roomType")
price = [price.text.strip().replace("â¹", "Rs.") for price in prices]

# %%
# Creating dictionary
new_df = pd.DataFrame({
    "Title":title,
    "Location": location,
    "Area": area,
    "EMI": emi,
    "Price": price
})
new_df
# Out:
#                                                 Title  \
# 0                1 BHK House for Rent  In Rajajinagar
# 1   2 BHK Apartment In Admiralty Square Gopalan, I...
# 2   2 BHK Flat In Standalone Building  for Rent  I...
# 3           1 RK Flat In Sb for Rent  In Rajaji Nagar
# 4   2 BHK House for Rent  In Laksmipuram, Indiranagar
# 5                      2 BHK for Rent  In Rajajinagar
# 6                3 BHK House for Rent  In Rajajinagar
# 7                 1 BHK House for Rent  In Siddhapura
# 8           2 BHK Flat for Rent  In Sk English School
# 9   2 BHK Apartment In Alpine Regency, Jayanagar f...
# 10  1 BHK Apartment In Brigade Gateway for Rent  I...
# 11  1 BHK Flat In Tropical Villa Apartments for Re...
# 12     3 BHK House for Rent  In Rajajinagar 5th Block
# 13  1 BHK Flat In Anjanadri Apartments  for Rent  ...
# 14                 2 BHK House for Rent  In Jayanagar
# 15  1 RK Apartment In Kerala Pavilion for Rent  In...
# ...
